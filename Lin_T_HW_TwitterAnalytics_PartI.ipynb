# %% [markdown]
# ** "On my honor, as a student, I have neither given nor received unauthorized aid on this academic work"**

# %%
import json

 
with open('movie.json', 'r') as f:
    line = f.readline() # read only the first tweet/line
    tweet = json.loads(line) # load it as Python dictionary
    print(json.dumps(tweet, indent=4)) 
    
# the original data from Twitter looks like below.
# Out:
# {
#     "quote_count": 0,
#     "contributors": null,
#     "truncated": false,
#     "text": "Balade Runner est un film long, difficile \u00e0 suivre parfois mais tellement fascinant. H\u00e2te de voir #BladeRunner2049 !",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "reply_count": 0,
#     "id": 918953409394470912,
#     "favorite_count": 0,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "timestamp_ms": "1507930540785",
#     "entities": {
#         "user_mentions": [],
#         "symbols": [],
#         "hashtags": [
#             {
#                 "indices": [
#                     98,
#                     114
#                 ],
#                 "text": "BladeRunner2049"
#             }
#         ],
#         "urls": []
#     },
#     "in_reply_to_screen_name": null,
#     "id_str": "918953409394470912",
#     "retweet_count": 0,
#     "in_reply_to_user_id": null,
#     "favorited": false,
#     "user": {
#         "follow_request_sent": null,
#         "profile_use_background_image": false,
#         "default_profile_image": false,
#         "id": 778225909232992256,
#         "default_profile": false,
#         "verified": false,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/915651010999341056/u1r7Th5g_normal.jpg",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "followers_count": 55,
#         "profile_sidebar_border_color": "000000",
#         "id_str": "778225909232992256",
#         "profile_background_color": "000000",
#         "listed_count": 1,
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "utc_offset": -25200,
#         "statuses_count": 1079,
#         "description": "\u30fd(\u30fb\u2200\u30fb)\uff89",
#         "friends_count": 158,
#         "location": null,
#         "profile_link_color": "FF691F",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/915651010999341056/u1r7Th5g_normal.jpg",
#         "following": null,
#         "geo_enabled": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/778225909232992256/1503820764",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "name": "Paul Gaultier",
#         "lang": "fr",
#         "profile_background_tile": false,
#         "favourites_count": 422,
#         "screen_name": "htxblog",
#         "notifications": null,
#         "url": "http://htxnews.wordpress.com",
#         "created_at": "Tue Sep 20 13:34:50 +0000 2016",
#         "contributors_enabled": false,
#         "time_zone": "Pacific Time (US & Canada)",
#         "protected": false,
#         "translator_type": "none",
#         "is_translator": false
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "lang": "fr",
#     "created_at": "Fri Oct 13 21:35:40 +0000 2017",
#     "filter_level": "low",
#     "in_reply_to_status_id_str": null,
#     "place": null
# }

# %%
import json

# create an empty list to store our tweets in
data = []

# append each line of the data to our tweets list using the json module
for line in open('movie.json'):
    try:
        data.append(json.loads(line))
    except:
        pass

# lets see how many we got
print len(data)
# Out:
# 81305

# %%
# read first five tweets only 
for i in data[:5]:
    print i['text']
# Out:
# Balade Runner est un film long, difficile à suivre parfois mais tellement fascinant. Hâte de voir #BladeRunner2049 !
# #BladeRunner2049 just reminded me what cinema is capable of. Phenomenal.
# Film of the year (pre-Star Wars, of course).
# RT @ecartelera: #Kingsman #ElCírculoDeOro no se podrá ver en Camboya porque ha sido CENSURADA https://t.co/qvDMlE8AKt https://t.co/dtwPFeSY…
# And this is why I absolutely adore @kelly_clarkson and @GalGadot! ❤️ https://t.co/HySMmntd4r
# RT @JoRoan: “If Asians shaped this cyberpunk future, where are they?”
# @shashashasha @eeeeenid @xuhulk @tealtan https://t.co/3KsuUfiOYa

# %%
# Read Sales dataset
import pandas as pd
df2 = pd.read_csv('movie_sales.csv')
df2.head()
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/numexpr/cpuinfo.py:42: UserWarning: [Errno 12] Cannot allocate memory
#   warnings.warn(str(e), UserWarning, stacklevel=stacklevel)
#                          Movie              hashtags    Sales
# 0            Blade Runner 2049       BladeRunner2049  7353151
# 1                American Made          AmericanMade  3131650
# 2  Kingsman: The Golden Circle              Kingsman  3011307
# 3      The Mountain Between Us  TheMountainBetweenUs  2773757
# 4           Victoria and Abdul      VictoriaAndAbdul  2126115

# %%
df2['hashtags'] = df2.hashtags.str.lower()

# %%
df2.head()
# Out:
#                          Movie              hashtags    Sales
# 0            Blade Runner 2049       bladerunner2049  7353151
# 1                American Made          americanmade  3131650
# 2  Kingsman: The Golden Circle              kingsman  3011307
# 3      The Mountain Between Us  themountainbetweenus  2773757
# 4           Victoria and Abdul      victoriaandabdul  2126115

# %%
# savin the entire tweets (not other data) in a variable and print it

texts = [ T['text'] for T in data if 'text' in T ]
len(texts)
# Out:
# 81297

# %%
for T in data:
    if 'text' not in T:
        print T
# Out:
# {u'limit': {u'track': 25, u'timestamp_ms': u'1508177709881'}}
# {u'limit': {u'track': 34, u'timestamp_ms': u'1508177714262'}}
# {u'limit': {u'track': 15, u'timestamp_ms': u'1508177721703'}}
# {u'limit': {u'track': 15, u'timestamp_ms': u'1508177723835'}}
# {u'limit': {u'track': 25, u'timestamp_ms': u'1508224526877'}}
# {u'limit': {u'track': 35, u'timestamp_ms': u'1508224529105'}}
# {u'limit': {u'track': 23, u'timestamp_ms': u'1508224552924'}}
# {u'limit': {u'track': 36, u'timestamp_ms': u'1508224597911'}}

# %%
# removing those error messages
tweets = []
for T in data:
    if 'text' in T:
        tweets.append(T)
len(tweets)
# Out:
# 81297

# %% [markdown]
# - The original tweets are 81297 data

# %%
# only English tweets & meta data
english_tweets = []
for i in tweets:
    if i['user']['lang'] == "en":
        english_tweets.append(i)
len(english_tweets)
# Out:
# 51678

# %% [markdown]
# - The english tweets are 51678

# %%
# Collecting all the data I want to analyze as variables
ids = [T['id_str'] for T in english_tweets]
times = [T['created_at'] for T in english_tweets]
screen_names = [T['user']['screen_name'] for T in english_tweets]
len(screen_names)
retweet_count = [T['retweet_count'] for T in english_tweets]
favorites_count = [T['user']['favourites_count'] for T in english_tweets]
place_names = [(T['place']['full_name'] if T['place'] else None) for T in english_tweets]
place_types = [(T['place']['place_type'] if T['place'] else None) for T in english_tweets]
followers_count = [status['user']['followers_count'] for status in english_tweets if 'user' in status]
friends_count = [status['user']['friends_count'] for status in english_tweets if 'user' in status]
texts = [ T['text'] for T in english_tweets if 'text' in T ]
len(texts)
# Out:
# 51678

# %%
# import popular packages
import csv
import pandas as pd

# %%
# open an output csv file to write to save all data
tweet_data = []

# merge each individual list into a single list using the zip function
rows = zip(ids,times, texts, screen_names, followers_count, friends_count, favorites_count)

# use one value from each of our rows list and write it to the csv as a new row
for row in rows:
    values = [(value.encode('utf8') if hasattr(value, 'encode') else value) for value in row]
    tweet_data.append(values)
tweet_data = pd.DataFrame(tweet_data) 
tweet_data.to_csv("tweet_data.csv")
tweet_data.head()
# Out:
#                     0                               1  \
# 0  918953414289231874  Fri Oct 13 21:35:41 +0000 2017
# 1  918953425332854784  Fri Oct 13 21:35:44 +0000 2017
# 2  918953451991814144  Fri Oct 13 21:35:50 +0000 2017
# 3  918953475492347904  Fri Oct 13 21:35:56 +0000 2017
# 4  918953486007619584  Fri Oct 13 21:35:59 +0000 2017
#
#                                                    2               3     4  \
# 0  #BladeRunner2049 just reminded me what cinema ...  charliehall300   184
# 1  And this is why I absolutely adore @kelly_clar...        dmcaputo   510
# 2  RT @JoRoan: “If Asians shaped this cyberpunk f...    shashashasha  5538
# 3  RT @annabellemovie: Evil is working overtime t...   VinceRemoTwit   180
# 4  RT @Kanerudo66: 'I want to show them all what ...        LIONPON3   246
#
#       5      6
# 0   391     39
# 1  1066   6710
# 2  1453  19898
# 3   191    505
# 4   228   9191

# %%
# Rename the header
tweet_data = tweet_data.rename(columns={0: 'id', 1: 'time', 2: 'texts', 3: 'Author_screen_name', 4: 'follower_count', 5: 'friends_count', 6: 'favorites_count'})

# %%
tweet_data.head()
# Out:
#                    id                            time  \
# 0  918953414289231874  Fri Oct 13 21:35:41 +0000 2017
# 1  918953425332854784  Fri Oct 13 21:35:44 +0000 2017
# 2  918953451991814144  Fri Oct 13 21:35:50 +0000 2017
# 3  918953475492347904  Fri Oct 13 21:35:56 +0000 2017
# 4  918953486007619584  Fri Oct 13 21:35:59 +0000 2017
#
#                                                texts Author_screen_name  \
# 0  #BladeRunner2049 just reminded me what cinema ...     charliehall300
# 1  And this is why I absolutely adore @kelly_clar...           dmcaputo
# 2  RT @JoRoan: “If Asians shaped this cyberpunk f...       shashashasha
# 3  RT @annabellemovie: Evil is working overtime t...      VinceRemoTwit
# 4  RT @Kanerudo66: 'I want to show them all what ...           LIONPON3
#
#    follower_count  friends_count  favorites_count
# 0             184            391               39
# 1             510           1066             6710
# 2            5538           1453            19898
# 3             180            191              505
# 4             246            228             9191

# %%
tweet_data['texts'] = tweet_data.texts.str.lower()

# %%
tweet_data['hashtags'] = tweet_data.texts.str.findall(r"(?<=#)\w+") 
tweet_data['retweet'] = tweet_data.texts.str.startswith("rt") 
tweet_data.head()
# Out:
#                    id                            time  \
# 0  918953414289231874  Fri Oct 13 21:35:41 +0000 2017
# 1  918953425332854784  Fri Oct 13 21:35:44 +0000 2017
# 2  918953451991814144  Fri Oct 13 21:35:50 +0000 2017
# 3  918953475492347904  Fri Oct 13 21:35:56 +0000 2017
# 4  918953486007619584  Fri Oct 13 21:35:59 +0000 2017
#
#                                                texts Author_screen_name  \
# 0  #bladerunner2049 just reminded me what cinema ...     charliehall300
# 1  and this is why i absolutely adore @kelly_clar...           dmcaputo
# 2  rt @joroan: “if asians shaped this cyberpunk f...       shashashasha
# 3  rt @annabellemovie: evil is working overtime t...      VinceRemoTwit
# 4  rt @kanerudo66: 'i want to show them all what ...           LIONPON3
#
#    follower_count  friends_count  favorites_count  \
# 0             184            391               39
# 1             510           1066             6710
# 2            5538           1453            19898
# 3             180            191              505
# 4             246            228             9191
#
#                                             hashtags retweet
# 0                                  [bladerunner2049]   False
# 1                                                 []   False
# 2                                                 []    True
# 3                 [fridaythe13th, annabellecreation]    True
# 4  [mlpfim, mlpmovie, mylittleponymovie, tempests...    True

# %%
tweet_data = pd.DataFrame({ 'screen_name': tweet_data['Author_screen_name'].repeat(tweet_data['hashtags'].str.len()), 'f_count': tweet_data['follower_count'].repeat(tweet_data['hashtags'].str.len()), 'fav_count': tweet_data['favorites_count'].repeat(tweet_data['hashtags'].str.len()), 'friends_count': tweet_data['friends_count'].repeat(tweet_data['hashtags'].str.len()), 'retweet': tweet_data['retweet'].repeat(tweet_data['hashtags'].str.len()), 'text': tweet_data['texts'].repeat(tweet_data['hashtags'].str.len()), 'hashtags': tweet_data['hashtags'].sum() })

# %%
tweet_data.head()
# Out:
#    f_count  fav_count  friends_count           hashtags retweet  \
# 0      184         39            391    bladerunner2049   False
# 3      180        505            191      fridaythe13th    True
# 3      180        505            191  annabellecreation    True
# 4      246       9191            228             mlpfim    True
# 4      246       9191            228           mlpmovie    True
#
#       screen_name                                               text
# 0  charliehall300  #bladerunner2049 just reminded me what cinema ...
# 3   VinceRemoTwit  rt @annabellemovie: evil is working overtime t...
# 3   VinceRemoTwit  rt @annabellemovie: evil is working overtime t...
# 4        LIONPON3  rt @kanerudo66: 'i want to show them all what ...
# 4        LIONPON3  rt @kanerudo66: 'i want to show them all what ...

# %%
import numpy as np
tweet_data['originaltweet_count'] = np.where(tweet_data['retweet'] == True, '0', '1')
tweet_data['retweet_count'] = np.where(tweet_data['retweet'] == True, '1', '0')
tweet_data['originaltweet_count'] = tweet_data['originaltweet_count'].astype(int)
tweet_data['retweet_count'] = tweet_data['retweet_count'].astype(int)

# %%
tweet_data.head()
# Out:
#    f_count  fav_count  friends_count           hashtags retweet  \
# 0      184         39            391    bladerunner2049   False
# 3      180        505            191      fridaythe13th    True
# 3      180        505            191  annabellecreation    True
# 4      246       9191            228             mlpfim    True
# 4      246       9191            228           mlpmovie    True
#
#       screen_name                                               text  \
# 0  charliehall300  #bladerunner2049 just reminded me what cinema ...
# 3   VinceRemoTwit  rt @annabellemovie: evil is working overtime t...
# 3   VinceRemoTwit  rt @annabellemovie: evil is working overtime t...
# 4        LIONPON3  rt @kanerudo66: 'i want to show them all what ...
# 4        LIONPON3  rt @kanerudo66: 'i want to show them all what ...
#
#    originaltweet_count  retweet_count
# 0                    1              0
# 3                    0              1
# 3                    0              1
# 4                    0              1
# 4                    0              1

# %%
# Drop all the data that hashtages are not our movie hashtags
common = tweet_data.merge(df2,on=['hashtags'])
len(common)
# Out:
# 44075

# %% [markdown]
# - Final dataset has 44075 data

# %%
tweet_data = common
tweet_data.head()
# Out:
#    f_count  fav_count  friends_count         hashtags retweet     screen_name  \
# 0      184         39            391  bladerunner2049   False  charliehall300
# 1       16        191             44  bladerunner2049    True    EMMAnimation
# 2     3305      10301           3093  bladerunner2049   False        istodius
# 3    86060     223268          38706  bladerunner2049   False    coachforward
# 4      234      10656            244  bladerunner2049   False      DoomBoxPro
#
#                                                 text  originaltweet_count  \
# 0  #bladerunner2049 just reminded me what cinema ...                    1
# 1  rt @thisisbenoliver: blade runner 2049 alterna...                    0
# 2  the longest 2.5 hours of my life...and, the mo...                    1
# 3  “i always told you. you're special. your histo...                    1
# 4  so... #bladerunner2049. really good movie, def...                    1
#
#    retweet_count              Movie    Sales
# 0              0  Blade Runner 2049  7353151
# 1              1  Blade Runner 2049  7353151
# 2              0  Blade Runner 2049  7353151
# 3              0  Blade Runner 2049  7353151
# 4              0  Blade Runner 2049  7353151

# %%
import pandas as pd
# number of hashtags in data
len(pd.unique(tweet_data.hashtags.ravel()))
# Out:
# 25

# %% [markdown]
# - Number of hashtages in my dataset is 25

# %%
import pandas as pd
# number of tweets
len(pd.unique(tweet_data.text.ravel()))
# Out:
# 18952

# %% [markdown]
# - Number of tweets is 18952

# %%
tweet_data.head()
# Out:
#    f_count  fav_count  friends_count         hashtags retweet     screen_name  \
# 0      184         39            391  bladerunner2049   False  charliehall300
# 1       16        191             44  bladerunner2049    True    EMMAnimation
# 2     3305      10301           3093  bladerunner2049   False        istodius
# 3    86060     223268          38706  bladerunner2049   False    coachforward
# 4      234      10656            244  bladerunner2049   False      DoomBoxPro
#
#                                                 text  originaltweet_count  \
# 0  #bladerunner2049 just reminded me what cinema ...                    1
# 1  rt @thisisbenoliver: blade runner 2049 alterna...                    0
# 2  the longest 2.5 hours of my life...and, the mo...                    1
# 3  “i always told you. you're special. your histo...                    1
# 4  so... #bladerunner2049. really good movie, def...                    1
#
#    retweet_count              Movie    Sales
# 0              0  Blade Runner 2049  7353151
# 1              1  Blade Runner 2049  7353151
# 2              0  Blade Runner 2049  7353151
# 3              0  Blade Runner 2049  7353151
# 4              0  Blade Runner 2049  7353151

# %%
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44075 entries, 0 to 44074
# Data columns (total 11 columns):
# f_count                44075 non-null int64
# fav_count              44075 non-null int64
# friends_count          44075 non-null int64
# hashtags               44075 non-null object
# retweet                44075 non-null bool
# screen_name            44075 non-null object
# text                   44075 non-null object
# originaltweet_count    44075 non-null int64
# retweet_count          44075 non-null int64
# Movie                  44075 non-null object
# Sales                  44075 non-null int64
# dtypes: bool(1), int64(6), object(4)
# memory usage: 3.7+ MB

# %%
# create new dataset, list the numbers as column
def f(x):
     return pd.Series(dict(hashtags=x['hashtags'].min(),
                        Number_of_tweets = x['text'].count(), 
                        number_of_follower= x['f_count'].sum(),
                        number_of_friends= x['friends_count'].sum(),
                        Number_of_user = x['screen_name'].nunique(),
                        Number_of_originaltweet = x['originaltweet_count'].sum(),
                        Number_of_retweet = x['retweet_count'].sum(),
                        Number_of_favorites_count = x['fav_count'].sum(),
                        Number_of_sales = x['Sales'].min(),
                        Movie = x['Movie'].min()
                        ))

# %%
df = tweet_data.groupby('hashtags').apply(f) 
print len(df)
df
# Out:
# 25
#                                             Movie  Number_of_favorites_count  \
# hashtags
# americanassassin                American Assassin                   10000465
# americanmade                        American Made                   10051775
# annabellecreation             Annabelle: Creation                    3670363
# aquestionoffaith              A Question of Faith                    1303444
# betterwatchout                   Better Watch Out                    1338252
# bladerunner2049                 Blade Runner 2049                  289679937
# bradsstatus                         Brad�s Status                     123470
# despicableme3                     Despicable Me 3                    2014051
# dunkirk                                   Dunkirk                   31511539
# emojimovie                        The Emoji Movie                    7046833
# flatliners                             Flatliners                    5411615
# friendrequest                      Friend Request                     379501
# hitmansbodyguard           The Hitman�s Bodyguard                     315385
# kidnap                                     Kidnap                    1823543
# kingsman              Kingsman: The Golden Circle                   20674851
# loganlucky                            Logan Lucky                      99494
# lovingvincent                      Loving Vincent                    7659520
# mlpmovie                My Little Pony: The Movie                   20993367
# spidermanhomecoming        Spider-Man: Homecoming                   37714073
# thekingschoice                  The King�s Choice                        731
# themountainbetweenus      The Mountain Between Us                    5569043
# viceroyshouse                     Viceroy's House                      33086
# victoriaandabdul               Victoria and Abdul                    7475833
# windriver                              Wind River                    1041632
# wonderwoman                          Wonder Woman                  201217228
#
#                       Number_of_originaltweet  Number_of_retweet  \
# hashtags
# americanassassin                          112                370
# americanmade                              438                307
# annabellecreation                         188                159
# aquestionoffaith                           27                 72
# betterwatchout                             88                 62
# bladerunner2049                          7392              15256
# bradsstatus                                18                  1
# despicableme3                             240                108
# dunkirk                                   151               1328
# emojimovie                                106                362
# flatliners                                130                399
# friendrequest                              19                 13
# hitmansbodyguard                           23                 11
# kidnap                                     79                 79
# kingsman                                  501               1166
# loganlucky                                 15                  7
# lovingvincent                             345                421
# mlpmovie                                  333               1030
# spidermanhomecoming                       621               1583
# thekingschoice                              3                  0
# themountainbetweenus                      207                 56
# viceroyshouse                               7                  7
# victoriaandabdul                          340                370
# windriver                                  95                 29
# wonderwoman                              3478               5923
#
#                       Number_of_sales  Number_of_tweets  Number_of_user  \
# hashtags
# americanassassin               163292               482             215
# americanmade                  3131650               745             563
# annabellecreation               61253               347             241
# aquestionoffaith                37190                99              71
# betterwatchout                   1825               150             118
# bladerunner2049               7353151             22648           17040
# bradsstatus                      6410                19              16
# despicableme3                  194730               348             167
# dunkirk                        100121              1479            1367
# emojimovie                     139203               468             362
# flatliners                     288022               529             467
# friendrequest                   10486                32              31
# hitmansbodyguard               105249                34              23
# kidnap                          19893               158             145
# kingsman                      3011307              1667            1125
# loganlucky                      23735                22              20
# lovingvincent                  429447               766             604
# mlpmovie                      2027064              1363             483
# spidermanhomecoming            160679              2204            1632
# thekingschoice                  11216                 3               3
# themountainbetweenus          2773757               263             198
# viceroyshouse                    7076                14              10
# victoriaandabdul              2126115               710             493
# windriver                       56088               124              99
# wonderwoman                     23385              9401            5971
#
#                                   hashtags  number_of_follower  \
# hashtags
# americanassassin          americanassassin              578321
# americanmade                  americanmade             6710528
# annabellecreation        annabellecreation              872529
# aquestionoffaith          aquestionoffaith              363212
# betterwatchout              betterwatchout             1167872
# bladerunner2049            bladerunner2049           172673430
# bradsstatus                    bradsstatus               27912
# despicableme3                despicableme3            24534521
# dunkirk                            dunkirk             3574369
# emojimovie                      emojimovie              569819
# flatliners                      flatliners             8986997
# friendrequest                friendrequest               22625
# hitmansbodyguard          hitmansbodyguard               30263
# kidnap                              kidnap              910935
# kingsman                          kingsman             4476608
# loganlucky                      loganlucky              756051
# lovingvincent                lovingvincent             3728618
# mlpmovie                          mlpmovie             1332748
# spidermanhomecoming    spidermanhomecoming            16692121
# thekingschoice              thekingschoice                3519
# themountainbetweenus  themountainbetweenus              847699
# viceroyshouse                viceroyshouse               94813
# victoriaandabdul          victoriaandabdul            17919706
# windriver                        windriver              573596
# wonderwoman                    wonderwoman            76171249
#
#                       number_of_friends
# hashtags
# americanassassin                 428152
# americanmade                    1670860
# annabellecreation                604789
# aquestionoffaith                 155932
# betterwatchout                  1010441
# bladerunner2049                29099976
# bradsstatus                       10441
# despicableme3                    393732
# dunkirk                         1785272
# emojimovie                       483872
# flatliners                       727424
# friendrequest                     28156
# hitmansbodyguard                  29611
# kidnap                           309724
# kingsman                        1312311
# loganlucky                        26694
# lovingvincent                    990107
# mlpmovie                        1030193
# spidermanhomecoming             3201811
# thekingschoice                     2691
# themountainbetweenus             281626
# viceroyshouse                     41804
# victoriaandabdul                1118958
# windriver                        212324
# wonderwoman                    18938561

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, americanassassin to wonderwoman
# Data columns (total 10 columns):
# Movie                        25 non-null object
# Number_of_favorites_count    25 non-null int64
# Number_of_originaltweet      25 non-null int64
# Number_of_retweet            25 non-null int64
# Number_of_sales              25 non-null int64
# Number_of_tweets             25 non-null int64
# Number_of_user               25 non-null int64
# hashtags                     25 non-null object
# number_of_follower           25 non-null int64
# number_of_friends            25 non-null int64
# dtypes: int64(8), object(2)
# memory usage: 2.1+ KB

# %%
# All the hashtags I use in this data set
tweet_data['hashtags'].unique()
# Out:
# array(['bladerunner2049', 'annabellecreation', 'mlpmovie', 'wonderwoman',
#        'kingsman', 'despicableme3', 'themountainbetweenus', 'flatliners',
#        'spidermanhomecoming', 'dunkirk', 'americanmade',
#        'hitmansbodyguard', 'windriver', 'friendrequest', 'emojimovie',
#        'lovingvincent', 'victoriaandabdul', 'betterwatchout',
#        'americanassassin', 'aquestionoffaith', 'kidnap', 'thekingschoice',
#        'loganlucky', 'viceroyshouse', 'bradsstatus'], dtype=object)

# %%
df.to_csv('moviesales.csv', index = False)

# %% [markdown]
# # Tweets per user

# %%
from collections import Counter

c = Counter(screen_names)
len(c)
# Out:
# 34720

# %%
#how many tweets per user?

float(51678/34720)
# Out:
# 1.0

# %%
# five most active tweeters
c.most_common(5)
# Out:
# [(u'BronyRetweets', 355),
#  (u'DespicableMe', 157),
#  (u'Kanerudo66', 133),
#  (u'64outsider', 100),
#  (u'rdd_deckard', 59)]

# %%
# make it pretty
activetweeters = c.most_common(5)
activetweeters_df = pd.DataFrame(activetweeters)
activetweeters_df
# Out:
#                0    1
# 0  BronyRetweets  355
# 1   DespicableMe  157
# 2     Kanerudo66  133
# 3     64outsider  100
# 4    rdd_deckard   59

# %%
#remove retweets
# Total originaltweets

originaltweets = []

for tweet in texts:
    if 'rt @' not in tweet.lower():
        originaltweets.append(tweet)
        
len(originaltweets)
# Out:
# 18432

# %%
# get retweets only
# Total retweets
retweets_only = []

for tweet in texts:
    if 'rt @' in tweet.lower():
        retweets_only.append(tweet)
        
len(retweets_only)
# Out:
# 33246

# %%
# The rate of retwees and original tweets
a = 33246/18432
print("%.3f" % round(a,3))
# Out:
# 1.000

# %% [markdown]
# - There are more retweets than original tweets, the number of original tweets is more than 50% of the number of rtweets

# %%
for i in retweets_only[:5]:
    print i
# Out:
# RT @JoRoan: “If Asians shaped this cyberpunk future, where are they?”
# @shashashasha @eeeeenid @xuhulk @tealtan https://t.co/3KsuUfiOYa
# RT @annabellemovie: Evil is working overtime this #Fridaythe13th. #AnnabelleCreation https://t.co/JHJC913vtW
# RT @Kanerudo66: 'I want to show them all what I can really do!'
# (By Paperdrop)
# #MLPFiM #MLPMovie #MyLittlePonyMovie #TempestShadow…
# RT @TheMarySue: [VIDEO]: #LukeEvans Calls @marstonmovie “a Revelation” https://t.co/XSMyCf7gwY #MarstonMovie #WonderWoman #comics…
# RT @Variety: .@KellyClarkson talks about her daughter's obsession with #WonderWoman (Watch) #PowerOfWomen presented by…

# %%
visible_users = []

for tweet in texts:
    a = re.findall(r"(?<=@)\w+", tweet)
    for i in a:
        visible_users.append(['@'+i])

# %%
#compute frequency distribution for visible users in the tweets
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords

#convert lists to strings
visible_users = str(visible_users)

#lowercase
visible_users = visible_users.lower()

#tokenize
visible_users = visible_users.split()

fdist = nltk.FreqDist(visible_users)

fdist.most_common(10)
# Out:
# [("[u'@bladerunner'],", 3296),
#  ("[u'@moviemantz'],", 2772),
#  ("[u'@imax'],", 2407),
#  ("[u'@amctheatres'],", 2168),
#  ("[u'@galgadot'],", 1827),
#  ("[u'@pattyjenks'],", 1365),
#  ("[u'@variety'],", 1313),
#  ("[u'@warnerbrosuk'],", 1089),
#  ("[u'@talenthouse'],", 841),
#  ("[u'@spidermanmovie'],", 813)]

# %%
# Regrestion model
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from scipy import stats
from pandas.tools import plotting
#regression packages
import sklearn.linear_model as lm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
import statsmodels.formula.api as sm
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import Jitter

#lasso regression
from sklearn import linear_model

#f_regression (feature selection)
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

# recursive feature selection (feature selection)
from sklearn.feature_selection import RFE
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aaefbfe0-9350-4763-9505-852d63a8f744">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Exploratory data

# %%
import pandas as pd
df = pd.read_csv('data/movieandsales.csv')
df.head()
# Out:
#                  Movie  Number_of_favorites_count  Number_of_originaltweet  \
# 0    American Assassin                   10000465                      112
# 1        American Made                   10051775                      438
# 2  Annabelle: Creation                    3670363                      188
# 3  A Question of Faith                    1303444                       27
# 4     Better Watch Out                    1338252                       88
#
#    Number_of_retweet  Number_of_sales  Number_of_tweets  Number_of_user  \
# 0                370           163292               482             215
# 1                307          3131650               745             563
# 2                159            61253               347             241
# 3                 72            37190                99              71
# 4                 62             1825               150             118
#
#    number_of_follower  number_of_friends
# 0              578321             428152
# 1             6710528            1670860
# 2              872529             604789
# 3              363212             155932
# 4             1167872            1010441

# %%
df.sort_values('Number_of_tweets', ascending=False).head()
# Out:
#                           Movie  Number_of_favorites_count  \
# 5             Blade Runner 2049                  289679937
# 24                 Wonder Woman                  201217228
# 18       Spider-Man: Homecoming                   37714073
# 14  Kingsman: The Golden Circle                   20674851
# 8                       Dunkirk                   31511539
#
#     Number_of_originaltweet  Number_of_retweet  Number_of_sales  \
# 5                      7392              15256          7353151
# 24                     3478               5923            23385
# 18                      621               1583           160679
# 14                      501               1166          3011307
# 8                       151               1328           100121
#
#     Number_of_tweets  Number_of_user  number_of_follower  number_of_friends
# 5              22648           17040           172673430           29099976
# 24              9401            5971            76171249           18938561
# 18              2204            1632            16692121            3201811
# 14              1667            1125             4476608            1312311
# 8               1479            1367             3574369            1785272

# %% [markdown]
# - The number of movies is 25
# - The top five movies in terms of tweets are Blade runner 2049, Wonder Woman, spider-man, Kingsman, Dunkirk

# %%
df.sort_values('Number_of_user', ascending=False).head()
# Out:
#                           Movie  Number_of_favorites_count  \
# 5             Blade Runner 2049                  289679937
# 24                 Wonder Woman                  201217228
# 18       Spider-Man: Homecoming                   37714073
# 8                       Dunkirk                   31511539
# 14  Kingsman: The Golden Circle                   20674851
#
#     Number_of_originaltweet  Number_of_retweet  Number_of_sales  \
# 5                      7392              15256          7353151
# 24                     3478               5923            23385
# 18                      621               1583           160679
# 8                       151               1328           100121
# 14                      501               1166          3011307
#
#     Number_of_tweets  Number_of_user  number_of_follower  number_of_friends
# 5              22648           17040           172673430           29099976
# 24              9401            5971            76171249           18938561
# 18              2204            1632            16692121            3201811
# 8               1479            1367             3574369            1785272
# 14              1667            1125             4476608            1312311

# %% [markdown]
# - I calculate the number of user based on the each text, so the number of user is equal to the number of tweet in this data
# - And if one Author has different tweets, they should be count by how many tweet with different hashtags they posted
# - But if they has post the same hashtags, they should be counted as one
# - The top five movies in terms of number of unique users are:
#     - Blade Runner 2049
#     - Wonder Woman
#     - Spider_Man: Homecoming
#     - Dunkirk
#     - Kingsman: The Golden Circle

# %%
df.sort_values('Number_of_sales', ascending=False).head()
# Out:
#                           Movie  Number_of_favorites_count  \
# 5             Blade Runner 2049                  289679937
# 1                 American Made                   10051775
# 14  Kingsman: The Golden Circle                   20674851
# 20      The Mountain Between Us                    5569043
# 22           Victoria and Abdul                    7475833
#
#     Number_of_originaltweet  Number_of_retweet  Number_of_sales  \
# 5                      7392              15256          7353151
# 1                       438                307          3131650
# 14                      501               1166          3011307
# 20                      207                 56          2773757
# 22                      340                370          2126115
#
#     Number_of_tweets  Number_of_user  number_of_follower  number_of_friends
# 5              22648           17040           172673430           29099976
# 1                745             563             6710528            1670860
# 14              1667            1125             4476608            1312311
# 20               263             198              847699             281626
# 22               710             493            17919706            1118958

# %% [markdown]
# - The top five movies in terms of movie sales are :Blade Runner 2049, American Made, the Mountain Between Us,Victoria and Abdul

# %%
# The total tweets in data sets
print df['Number_of_tweets'].sum()
# How many tweets for each movie
print float(44075/25)
# The number of users
print df['Number_of_user'].sum()
# How many users for each movie
print float(31464/25)
# Out:
# 44075
# 1763.0
# 31464
# 1258.0

# %% [markdown]
# - The number of total tweets is 44075, each movie has 1763 tweets
# - The number of unique users is 31464, each movie has 1258 users

# %%
# General realationship between each variables
df.corr()
# Out:
#                            Number_of_favorites_count  Number_of_originaltweet  \
# Number_of_favorites_count                   1.000000                 0.979242
# Number_of_originaltweet                     0.979242                 1.000000
# Number_of_retweet                           0.968707                 0.992707
# Number_of_sales                             0.621650                 0.721202
# Number_of_tweets                            0.973770                 0.996733
# Number_of_user                              0.958778                 0.991300
# number_of_follower                          0.961696                 0.989336
# number_of_friends                           0.996914                 0.987483
#
#                            Number_of_retweet  Number_of_sales  \
# Number_of_favorites_count           0.968707         0.621650
# Number_of_originaltweet             0.992707         0.721202
# Number_of_retweet                   1.000000         0.729314
# Number_of_sales                     0.729314         1.000000
# Number_of_tweets                    0.999200         0.727805
# Number_of_user                      0.998347         0.740359
# number_of_follower                  0.981525         0.702926
# number_of_friends                   0.973481         0.636004
#
#                            Number_of_tweets  Number_of_user  \
# Number_of_favorites_count          0.973770        0.958778
# Number_of_originaltweet            0.996733        0.991300
# Number_of_retweet                  0.999200        0.998347
# Number_of_sales                    0.727805        0.740359
# Number_of_tweets                   1.000000        0.997626
# Number_of_user                     0.997626        1.000000
# number_of_follower                 0.985705        0.982656
# number_of_friends                  0.979701        0.966990
#
#                            number_of_follower  number_of_friends
# Number_of_favorites_count            0.961696           0.996914
# Number_of_originaltweet              0.989336           0.987483
# Number_of_retweet                    0.981525           0.973481
# Number_of_sales                      0.702926           0.636004
# Number_of_tweets                     0.985705           0.979701
# Number_of_user                       0.982656           0.966990
# number_of_follower                   1.000000           0.973434
# number_of_friends                    0.973434           1.000000

# %%
# correlation heatmap
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# - number_of_favorite_count, number_of_riginaltweets,number_of_retweets, number_of_tweets, number_of_users, number_of_followers and number_of_frineds
# -have strong relationship with number_of_sales, especially number_of_retweet, number_of_tweet.
# - Number_ of_friends  and number_of_favorite_count,have the least imfluence on sales, but the correlation is still 64% and 62%, which is more than 50%

# %%
# Regresion model

# %%
# Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn import linear_model
from sklearn.linear_model import Lasso
y = df['Number_of_sales'] 
X = df.drop(['Number_of_sales'], axis =1)
model1 = linear_model.Lasso(alpha = 1)        #higher alpha (penality parameter), fewer predictors
model1.fit(X, y)
model1_y = model1.predict(X)
print 'Coefficients: ', model1.coef_
print "y-intercept ", model1.intercept_
print "mean square error: ", mean_squared_error(y, model1_y)
print "variance or r-squared: ", explained_variance_score(y, model1_y)
# Out:
# Coefficients:  [  4.94258403e-02   7.05422900e+03  -9.77512299e+02   2.15622019e+02
#    4.79891238e+01  -3.92393822e-02  -1.49114954e+00]
# y-intercept  399869.271892
# mean square error:  561179989697.0
# variance or r-squared:  0.799151092418
# /anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# - Model1 has 0.7915 variance scores, and mean square error is 0.561179989697e+12

# %%
#visualize actural vs. predictive using scatter plot
plt.subplots()
plt.scatter(y, model1_y)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)   #dotted line represents perfect prediction (actual = predicted)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
# Print out the variables and its coef_
pd.DataFrame(zip(X.columns, np.transpose(model1.coef_)))
# Out:
#                            0            1
# 0  Number_of_favorites_count     0.049426
# 1    Number_of_originaltweet  7054.229004
# 2          Number_of_retweet  -977.512299
# 3           Number_of_tweets   215.622019
# 4             Number_of_user    47.989124
# 5         number_of_follower    -0.039239
# 6          number_of_friends    -1.491150

# %%
# Select two vanuables
#selec only 2 X variables, which are best fit
X_new = SelectKBest(f_regression, k=2).fit_transform(X, y)
model2 = lm.LinearRegression()
model2.fit(X_new, y)
model2_y = model2.predict(X_new)

print "mean square error: ", mean_squared_error(y, model2_y)
print "variance or r-squared: ", explained_variance_score(y, model2_y)
print 'Coefficients: ', model2.coef_
print "y-intercept ", model2.intercept_
# Out:
# mean square error:  1.18098537621e+12
# variance or r-squared:  0.57731988482
# Coefficients:  [-1598.49233487  1807.38685917]
# y-intercept  477648.886479

# %% [markdown]
#  - Model2 has 0.5773 variance, which is low, and 1.18098537621e+12 mean square error

# %%
#visualize actural vs. predictive using scatter plot
plt.subplots()
plt.scatter(y, model2_y)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)   #dotted line represents perfect prediction (actual = predicted)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
# Ridge
from sklearn import linear_model
from sklearn.linear_model import Ridge
import numpy as np
#assigning columns to X and Y variables
y = df['Number_of_sales'] 
X = df.drop(['Number_of_sales'], axis =1)
model3 = linear_model.Ridge (alpha = .1)
model3.fit (X,y) 
model3_y = model3.predict(X)
Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
      normalize=False, random_state=None, solver='auto', tol=0.001)
print model3.coef_
print model3.intercept_ 
print "mean square error: ", mean_squared_error(y, model3_y)
print "variance or r-squared: ", explained_variance_score(y, model3_y)
# Out:
# [  7.63936593e-02   5.74258682e+03  -3.62063428e+03   2.12195237e+03
#    5.32111081e+02  -3.87381211e-02  -1.81014314e+00]
# 381729.734545
# mean square error:  555121406630.0
# variance or r-squared:  0.801319487251

# %% [markdown]
# - Model3 has 0.801319487251 variance score, and mean square error:  0.555121406630e+12

# %%
plt.subplots()
plt.scatter(y, model3_y)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)   #dotted line represents perfect prediction (actual = predicted)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
# Print out the variables and coef_ in model3
pd.DataFrame(zip(X.columns, np.transpose(model3.coef_)))
# Out:
#                            0            1
# 0  Number_of_favorites_count     0.076394
# 1    Number_of_originaltweet  5742.586822
# 2          Number_of_retweet -3620.634277
# 3           Number_of_tweets  2121.952367
# 4             Number_of_user   532.111081
# 5         number_of_follower    -0.038738
# 6          number_of_friends    -1.810143

# %%
import statsmodels.formula.api as sm
runs_reg_model3 = sm.ols("Number_of_sales~Number_of_favorites_count+Number_of_originaltweet+Number_of_retweet+Number_of_tweets+Number_of_user+number_of_follower+number_of_friends",df)
runs_reg3 = runs_reg_model3.fit()
print runs_reg3.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Number_of_sales   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     12.10
# Date:                Tue, 31 Oct 2017   Prob (F-statistic):           1.79e-05
# Time:                        15:44:10   Log-Likelihood:                -373.50
# No. Observations:                  25   AIC:                             761.0
# Df Residuals:                      18   BIC:                             769.5
# Df Model:                           6
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  3.817e+05   1.95e+05      1.953      0.067    -2.9e+04    7.92e+05
# Number_of_favorites_count     0.0764      0.065      1.178      0.254      -0.060       0.213
# Number_of_originaltweet    5742.5904   1730.018      3.319      0.004    2107.958    9377.223
# Number_of_retweet         -3620.6376   1669.714     -2.168      0.044   -7128.577    -112.698
# Number_of_tweets           2121.9527    803.725      2.640      0.017     433.390    3810.515
# Number_of_user              532.1127   1574.672      0.338      0.739   -2776.150    3840.375
# number_of_follower           -0.0387      0.036     -1.087      0.291      -0.114       0.036
# number_of_friends            -1.8101      0.759     -2.384      0.028      -3.405      -0.215
# ==============================================================================
# Omnibus:                        5.704   Durbin-Watson:                   2.898
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                4.337
# Skew:                           1.014   Prob(JB):                        0.114
# Kurtosis:                       3.221   Cond. No.                     2.53e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.57e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Randon Forest
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier

model4 = RandomForestClassifier()
#higher alpha (penality parameter), fewer predictors
model4.fit(X, y)
model4_y = model1.predict(X)
print "mean square error: ", mean_squared_error(y, model4_y)
print "variance or r-squared: ", explained_variance_score(y, model4_y)
# Out:
# mean square error:  561179989697.0
# variance or r-squared:  0.799151092418
# /anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# - Model4 has 0.79915 variance score, and mean square error:  0.561179989697e+12

# %% [markdown]
# # Best Model

# %% [markdown]
# - The smaller the means squared error, the closer you are to finding the line of best fit. Depending on my data,  the sales of movies are large numbers, so it may be impossible to get a very small value for the mean squared error.
# - R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression. 0% indicates that the model explains none of the variability of the response data around its mean.
# - Correlation is used to give information about the relationship between x and y.  When the regression equation is calculated, the corelation results indicate the nature and the strength of the relationship.
#   - in correlation coef_ sheet, all the variables has high positive relationship with y, but in my modle3, Number_of_retweet, Number_of_followers, and number_of_friends has negative coef_, which mean negative relationship.
#
# ** Model3 has the highest R-squared with 80% and lower mean square error than the other three models**
#
# ** The regresion of sales and the other variables is:**
#     - Number of sales = 0.0764 f_count+5742.5904number_of_originaltweet-3620.6376Number_of_retweet+2121.9527Number_of_tweet+532.1127Number_of_user-0.0387number_of_follower-1.8101number_of_friends
#
# -Even though the the cope of f_count, number_of_folower, number_of_friends is small, but the number of these three variabbles are large, so these three variables are also important in this modle

# %% [markdown]
# # Part 2, Modely Deployment : Predictive Analytics (Predicting Y value)

# %%
# We use model3 to predict y value. 
scoring = pd.read_csv("moviesales2.csv")
scoring.head()
# Out:
#                  Movie  Number_of_favorites_count  Number_of_originaltweet  \
# 0    American Assassin                    3730314                       88
# 1        American Made                     790869                       31
# 2  Annabelle: Creation                    1001732                       16
# 3    Blade Runner 2049                    4372079                      235
# 4      Despicable Me 3                    3492605                       40
#
#    Number_of_retweet  Number_of_sales  Number_of_tweets  Number_of_user  \
# 0                126          1388305               148             107
# 1                 31          1695000                62              59
# 2                 23           147702                39              37
# 3                238          3965000               473             414
# 4                349           145000               389             354
#
#    number_of_follower  number_of_friends
# 0              221483             183704
# 1              368011             233668
# 2              151095              82591
# 3             1631039             873377
# 4             3024604             891441

# %% [markdown]
# - Total have 12 hashtags
# - The number of movies is 12 in second round dataset, almost 50% of movies are not sold last week.

# %%
scoring['Number_of_originaltweet'] = scoring['Number_of_originaltweet']*3
scoring['Number_of_retweet'] = scoring['Number_of_retweet']*3
scoring['Number_of_tweets'] = scoring['Number_of_tweets']*3
scoring['Number_of_user'] = scoring['Number_of_user']*3
scoring.head()
# Out:
#                  Movie  Number_of_favorites_count  Number_of_originaltweet  \
# 0    American Assassin                    3730314                      264
# 1        American Made                     790869                       93
# 2  Annabelle: Creation                    1001732                       48
# 3    Blade Runner 2049                    4372079                      705
# 4      Despicable Me 3                    3492605                      120
#
#    Number_of_retweet  Number_of_sales  Number_of_tweets  Number_of_user  \
# 0                378          1388305               444             321
# 1                 93          1695000               186             177
# 2                 69           147702               117             111
# 3                714          3965000              1419            1242
# 4               1047           145000              1167            1062
#
#    number_of_follower  number_of_friends
# 0              221483             183704
# 1              368011             233668
# 2              151095              82591
# 3             1631039             873377
# 4             3024604             891441

# %% [markdown]
# - Because the collecting between Ubuntu server interupted automatively, I have only collect one day data on 24
# - Trying to be more correct, I use Number_of_riginaltweet, Number_of_retweet, number_of_tweet and number of user times 3 ,to predict the three days data, the same days the same as the first round

# %%
# The number of movies
len(scoring)
# The number of tweets
print scoring['Number_of_tweets'].sum()
# The number of users
print scoring['Number_of_user'].sum()
# The number of original tweet
print scoring['Number_of_originaltweet'].sum()
# the number of retweet
print scoring['Number_of_retweet'].sum()
# Out:
# 3933
# 3402
# 1437
# 2694

# %% [markdown]
# - the rate of original tweets and retweets is 1437/2694, 53% which is lower than the first round.
#
# **The number of tweets**
#
# -Since the discollecting of my Ubuntu server, I only collect data on Oct 24th, , so my dataset has only 6747 data.
#
# -if use this number times 4 days, the same days of my first round, the dataset should be close. because many of my movies in my dataset
# -have been released by more than 2months, so the number of tweets should be stable everyday.
#
# -but for those which just released for one or two weeks, the number of tweets should increase, which is small number in my dataset.
#
# -for those already released more than three weeks the tweets will declined

# %%
# the number of twets per movie
print float(3933/12)
# the number of users per movie
print float(3402/12)
# Out:
# 327.0
# 283.0

# %% [markdown]
# - each movie has 327 tweets by 283 user on Oct 24, which means each user post one tweet in average

# %%
scoring.sort_values('Number_of_tweets', ascending=False).head()
# Out:
#                        Movie  Number_of_favorites_count  \
# 3          Blade Runner 2049                    4372079
# 4            Despicable Me 3                    3492605
# 0          American Assassin                    3730314
# 9  My Little Pony: The Movie                    1387801
# 1              American Made                     790869
#
#    Number_of_originaltweet  Number_of_retweet  Number_of_sales  \
# 3                      705                714          3965000
# 4                      120               1047           145000
# 0                      264                378          1388305
# 9                       54                243          8885899
# 1                       93                 93          1695000
#
#    Number_of_tweets  Number_of_user  number_of_follower  number_of_friends
# 3              1419            1242             1631039             873377
# 4              1167            1062             3024604             891441
# 0               444             321              221483             183704
# 9               297             216               56865              56435
# 1               186             177              368011             233668

# %%
scoring.sort_values('Number_of_user', ascending=False).head()
# Out:
#                        Movie  Number_of_favorites_count  \
# 3          Blade Runner 2049                    4372079
# 4            Despicable Me 3                    3492605
# 0          American Assassin                    3730314
# 9  My Little Pony: The Movie                    1387801
# 1              American Made                     790869
#
#    Number_of_originaltweet  Number_of_retweet  Number_of_sales  \
# 3                      705                714          3965000
# 4                      120               1047           145000
# 0                      264                378          1388305
# 9                       54                243          8885899
# 1                       93                 93          1695000
#
#    Number_of_tweets  Number_of_user  number_of_follower  number_of_friends
# 3              1419            1242             1631039             873377
# 4              1167            1062             3024604             891441
# 0               444             321              221483             183704
# 9               297             216               56865              56435
# 1               186             177              368011             233668

# %%
scoring.sort_values('Number_of_sales', ascending=False).head()
# Out:
#                         Movie  Number_of_favorites_count  \
# 9   My Little Pony: The Movie                    1387801
# 5                  Flatliners                      65530
# 3           Blade Runner 2049                    4372079
# 1               American Made                     790869
# 11         Victoria and Abdul                     344528
#
#     Number_of_originaltweet  Number_of_retweet  Number_of_sales  \
# 9                        54                243          8885899
# 5                        21                 18          3975021
# 3                       705                714          3965000
# 1                        93                 93          1695000
# 11                       33                 39          1612000
#
#     Number_of_tweets  Number_of_user  number_of_follower  number_of_friends
# 9                297             216               56865              56435
# 5                 39              30                5674              13167
# 3               1419            1242             1631039             873377
# 1                186             177              368011             233668
# 11                72              54              559902              22761

# %%
# collect the columns that I use as variables, and get the result of sales of each movies
columns = scoring[['Number_of_favorites_count', 'Number_of_originaltweet', 'Number_of_retweet', 'Number_of_tweets', 'Number_of_user', 'number_of_follower', 'number_of_friends']]
sales = model3.predict(columns)

sales
# Out:
# array([ 1585989.37276738,   691126.91784442,   636054.19843613,
#         4206931.28354929, -1142533.96519848,   516824.23722707,
#          406101.57441787,   375595.16637889,   866799.61877039,
#          558832.06543   ,   533747.50491027,   574974.46679731])

# %%
scoring['Number_of_sales']
# Out:
# 0     1388305
# 1     1695000
# 2      147702
# 3     3965000
# 4      145000
# 5     3975021
# 6        5122
# 7      168367
# 8     1600000
# 9     8885899
# 10    1300000
# 11    1612000
# Name: Number_of_sales, dtype: int64

# %% [markdown]
# # References

# %% [markdown]
# **https://stackoverflow.com/questions/148042/using-or-comparisons-with-if-statements**
#
# **https://stackoverflow.com/questions/148042/using-or-comparisons-with-if-statements**
#
# **https://stackoverflow.com/questions/38905031/name-classification-model-is-not-defined**
#
# **https://stackoverflow.com/questions/20107570/removing-index-column-in-pandas**
